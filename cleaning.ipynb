# %%
# preferred in notebooks

import pandas as pd

df = pd.read_csv('./data/un-country-data.csv')

countries = df[df['ISO3_code'].notnull()]

colunns = ['ISO3_code', 'Location','Time', 'TPopulation1Jan', 'TPopulation1July']

clean_df = countries[colunns]

clean_df.to_csv('./data/cleaned-data.csv', index=False)
# Out:
# /var/folders/n6/79p7bkqj6ql902690ngw1fn40000gn/T/ipykernel_67882/325248202.py:5: DtypeWarning: Columns (2,3,4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/un-country-data.csv')
